# %%
from pathlib import Path
import yaml

REPO = Path.cwd().parent
p = yaml.safe_load((REPO/"data/policies_synth_md/system_profile.yaml").read_text())
p["organization"]["name"], p["system"]["name"], p["system"].get("system_type"), p["posture"]["statement"]
# Out:
# ('Rivermark Logistics (Fictional)',
#  'Rivermark Operations Portal (ROP) (Fictional)',
#  ['Web App', 'API', 'Database'],
#  'Baseline-like posture for demo only; not an official categorization or DoD baseline.')

# %%
from pathlib import Path
import yaml

REPO = Path.cwd().parent
p = yaml.safe_load((REPO/"data/policies_synth_md/system_profile.yaml").read_text())

p["posture"]["statement"]
# Out:
# 'Baseline-like posture for demo only; not an official categorization or DoD baseline.'
