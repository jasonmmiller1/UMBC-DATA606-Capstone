# %%
import sys
sys.executable
# Out:
# '/home/jaz3n/miniconda3/envs/rmf-assistant/bin/python'

# %%
from pathlib import Path
Path.cwd()
# Out:
# PosixPath('/home/jaz3n/Repository/UMBC-DATA606-Capstone/notebooks')

# %%
from pathlib import Path
list(Path(".").rglob("system_profile.yaml"))[:20]
# Out:
# []

# %%
import yaml
from pathlib import Path

profile_path = Path("data/policies_synth_md/system_profile.yaml")
profile = yaml.safe_load(profile_path.read_text())
profile["organization"]["name"], profile["system"]["name"]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 5
#       2 from pathlib import Path
#       4 profile_path = Path("data/policies_synth_md/system_profile.yaml")
# ----> 5 profile = yaml.safe_load(profile_path.read_text())
#       6 profile["organization"]["name"], profile["system"]["name"]
#
# File ~/miniconda3/envs/rmf-assistant/lib/python3.10/pathlib.py:1134, in Path.read_text(self, encoding, errors)
#    1130 """
#    1131 Open the file in text mode, read it, and close the file.
#    1132 """
#    1133 encoding = io.text_encoding(encoding)
# -> 1134 with self.open(mode='r', encoding=encoding, errors=errors) as f:
#    1135     return f.read()
#
# File ~/miniconda3/envs/rmf-assistant/lib/python3.10/pathlib.py:1119, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1117 if "b" not in mode:
#    1118     encoding = io.text_encoding(encoding)
# ...
